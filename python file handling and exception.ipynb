# %%
#file handling and exception

# %%
#file handling is used to read,write and manage files

# %%
Modes:
"r" → Read (default)
"w" → Write (overwrites file)
"a" → Append (adds data)
"x" → Create new file
"b" → Binary mode

# %%
#write

# %%
file = open("data.txt","w")
file.write("hello i am a bba finance student ")
file.close()

# %%
#reading

# %%
file = open("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello i am a bba finance student

# %%
#append add new lines

# %%
file = open("data.txt","a")
file.write(" add new line ")
file.close()

# %%
file = open("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello i am a bba finance student in new linesas a finance student i am very intersted to take data driven business decisions as a finance student i am very intersted to take data driven business decisions add new line  add new line

# %%
with open("data.txt", "w") as file:
    pass

# %%
file = open("data.txt","r")
content = file.read()
print(content)
file.close()

# %%
file = open("data.txt","w")
file.write(" hello i am bba finance student ")
file.close()

# %%
file = open("data.txt","a")
file.write( " as a finance student i am interested to take data driven business decisions so i decided to learn python " )
file.close()

# %%
file = open ("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
#  hello i am bba finance student  as a finance student i am interested to take data driven business decisions so i decided to learn python

# %%
file = open("data.txt","a")
file.write ("for finance currently i am learning file handling and exception ")
file.close()

# %%
file = open("data.txt","r")
content = file.read()
print(content)
file.close()
# Out:
#  hello i am bba finance student  as a finance student i am interested to take data driven business decisions so i decided to learn python for finance currently i am learning file handling and exception

# %%
#Exception Handling in Python

# %%
#Exception handling is used to handle errors without crashing the program.

# %%
try:
    a = int(input("enter number: "))
    print(10 / a)
except:
    print("error occured")
# Out:
# enter number:  -1
# -10.0
