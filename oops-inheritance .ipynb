# %%
#inheritance 
#when one class use properties of another class
class car:
    @staticmethod 
    def start():
        print("car started...")

        @staticmethod 
        def start():
            print("car stopped...")

class toyotacar(car):
    def __init__(self,name):
        self.name=name

car1 = toyotacar("fortuner")
car2 = toyotacar("prius")

print(car1.start())
# Out:
# car started...
# None
